# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/ingredients_edited.csv')
df2 = pd.read_csv('data/ingredients_edited.csv')

# %%
df2['Alpha Carotene'] = (df2['Alpha Carotene'] / 1000)
df2['Beta Carotene'] = (df2['Beta Carotene'] / 1000)
df2['Beta Cryptoxanthin'] = (df2['Beta Cryptoxanthin'] / 1000)
df2['Carbohydrate'] = (df2['Carbohydrate'] * 100).round(2)
df2['Fiber'] = (df2['Fiber'] * 100).round(2)
df2['Lutein and Zeaxanthin'] = (df2['Lutein and Zeaxanthin'] / 1000)
df2['Lycopene'] = (df2['Lycopene'] / 1000)
df2['Protein'] = (df2['Protein'] * 100)
df2['Retinol'] = (df2['Retinol'] / 1000)
df2['Selenium'] = (df2['Selenium'] / 1000)

df2['Sugar Total'] = (df2['Sugar Total'] * 100)
df2['Water'] = (df2['Water'] * 100).round(2)
df2['Monosaturated Fats'] = (df2['Monosaturated Fats'] * 100)
df2['Polysaturated Fats'] = (df2['Polysaturated Fats'] * 100)
df2['Saturated Fats'] = (df2['Saturated Fats'] * 100)
df2['Lipids'] = (df2['Lipids'] * 100)

df2['Vitamin A - RAE'] = (df2['Vitamin A - RAE'] / 1000)
df2['Vitamin B12'] = (df2['Vitamin B12'] / 1000)
df2['Vitamin K'] = (df2['Vitamin K'] / 1000)

# %%
df2
# Out:
#    Category     Description  Nutrient Data Bank Number  Alpha Carotene  \
# 0    Cheese            Blue                       1004           0.000
# 1    Cheese            Brie                       1006           0.000
# 2    Cheese       Camembert                       1007           0.000
# 3    Cheese        Cheddar                        1009           0.000
# 4    Cheese           Colby                       1011           0.000
# ..      ...             ...                        ...             ...
# 72      Pie  Lemon Meringue                      18320           0.000
# 73      Pie           Peach                      18323           0.000
# 74      Pie           Pecan                      18324           0.000
# 75      Pie         Pumpkin                      18326           0.686
# 76      Pie   Vanilla Cream                      18328           0.002
#
#     Beta Carotene  Beta Cryptoxanthin  Carbohydrate  Cholesterol  Choline  \
# ...

# %%
df2 = df2.round(3)

# %%
df2
# Out:
#    Category     Description  Nutrient Data Bank Number  Alpha Carotene  \
# 0    Cheese            Blue                       1004           0.000
# 1    Cheese            Brie                       1006           0.000
# 2    Cheese       Camembert                       1007           0.000
# 3    Cheese        Cheddar                        1009           0.000
# 4    Cheese           Colby                       1011           0.000
# ..      ...             ...                        ...             ...
# 72      Pie  Lemon Meringue                      18320           0.000
# 73      Pie           Peach                      18323           0.000
# 74      Pie           Pecan                      18324           0.000
# 75      Pie         Pumpkin                      18326           0.686
# 76      Pie   Vanilla Cream                      18328           0.002
#
#     Beta Carotene  Beta Cryptoxanthin  Carbohydrate  Cholesterol  Choline  \
# ...

# %%
df
# Out:
#    Category     Description  Nutrient Data Bank Number  Alpha Carotene  \
# 0    Cheese            Blue                       1004               0
# 1    Cheese            Brie                       1006               0
# 2    Cheese       Camembert                       1007               0
# 3    Cheese        Cheddar                        1009               0
# 4    Cheese           Colby                       1011               0
# ..      ...             ...                        ...             ...
# 72      Pie  Lemon Meringue                      18320               0
# 73      Pie           Peach                      18323               0
# 74      Pie           Pecan                      18324               0
# 75      Pie         Pumpkin                      18326             686
# 76      Pie   Vanilla Cream                      18328               2
#
#     Beta Carotene  Beta Cryptoxanthin  Carbohydrate  Cholesterol  Choline  \
# ...

# %%
df2.to_csv('data/ingredients_mg.csv')
